# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000,90.000, size = 2000)
lngs = np.random.uniform(-180, 180, size =2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
          
        # Append the city information into the city_data list
        city_data.append({"city":city.title(),
                          "lat":city_lat,
                          "Lng":city_lng,
                          "Max temp" : city_max_temp,
                          "Humidity" : city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country" : city_country,
                          "Current Description" : city_weather_desc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | igarka
# Processing Record 2 of Set 1 | mpanda
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | bagdarin
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | payson
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | saldanha
# Processing Record 12 of Set 1 | alyangula
# Processing Record 13 of Set 1 | saskylakh
# Processing Record 14 of Set 1 | sisimiut
# Processing Record 15 of Set 1 | gazli
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | bathsheba
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | huilong
# Processing Record 20 of Set 1 | olyka
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | sur
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | arrecife
# Processing Record 26 of Set 1 | ribeira grande
# Processing Record 27 of Set 1 | lompoc
# Processing Record 28 of Set 1 | carnarvon
# Processing Record 29 of Set 1 | mangrol
# Processing Record 30 of Set 1 | falealupo
# City not found. Skipping...
# Processing Record 31 of Set 1 | naze
# Processing Record 32 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 33 of Set 1 | saint george
# Processing Record 34 of Set 1 | hualmay
# Processing Record 35 of Set 1 | tasiilaq
# Processing Record 36 of Set 1 | pevek
# Processing Record 37 of Set 1 | college
# Processing Record 38 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | tuktoyaktuk
# Processing Record 43 of Set 1 | kodiak
# Processing Record 44 of Set 1 | manokwari
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | ancud
# Processing Record 47 of Set 1 | kysyl-syr
# Processing Record 48 of Set 1 | berlevag
# Processing Record 49 of Set 1 | canavieiras
# Processing Record 50 of Set 1 | souillac
# Processing Record 1 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | khatanga
# Processing Record 4 of Set 2 | leshukonskoye
# Processing Record 5 of Set 2 | bethel
# Processing Record 6 of Set 2 | bredasdorp
# Processing Record 7 of Set 2 | gotsu
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | ambilobe
# Processing Record 10 of Set 2 | omsukchan
# Processing Record 11 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 2 | padang
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | itaituba
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | esperance
# Processing Record 19 of Set 2 | cherskiy
# Processing Record 20 of Set 2 | talara
# Processing Record 21 of Set 2 | plettenberg bay
# Processing Record 22 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 2 | ngerengere
# Processing Record 24 of Set 2 | olafsvik
# Processing Record 25 of Set 2 | katsuura
# Processing Record 26 of Set 2 | saint-philippe
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | makinsk
# Processing Record 29 of Set 2 | honiara
# Processing Record 30 of Set 2 | matamoros
# Processing Record 31 of Set 2 | shaowu
# Processing Record 32 of Set 2 | fairfield
# Processing Record 33 of Set 2 | airai
# Processing Record 34 of Set 2 | langfang
# Processing Record 35 of Set 2 | victoria
# Processing Record 36 of Set 2 | zhigansk
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | aksu
# Processing Record 39 of Set 2 | faya
# Processing Record 40 of Set 2 | qui nhon
# Processing Record 41 of Set 2 | lima
# Processing Record 42 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 2 | kamina
# Processing Record 44 of Set 2 | kirkwall
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | tahta
# Processing Record 47 of Set 2 | san vicente
# Processing Record 48 of Set 2 | vanderhoof
# Processing Record 49 of Set 2 | la ronge
# Processing Record 50 of Set 2 | guerrero negro
# Processing Record 1 of Set 3 | nome
# Processing Record 2 of Set 3 | clyde river
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | lincoln
# Processing Record 5 of Set 3 | mahebourg
# Processing Record 6 of Set 3 | izumo
# Processing Record 7 of Set 3 | meadow lake
# Processing Record 8 of Set 3 | jaicos
# Processing Record 9 of Set 3 | encheng
# Processing Record 10 of Set 3 | vorsma
# Processing Record 11 of Set 3 | tiksi
# Processing Record 12 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 3 | ballina
# Processing Record 14 of Set 3 | ponta delgada
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | kamenka
# Processing Record 17 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 18 of Set 3 | areka
# Processing Record 19 of Set 3 | provideniya
# Processing Record 20 of Set 3 | tondano
# Processing Record 21 of Set 3 | luau
# Processing Record 22 of Set 3 | raga
# Processing Record 23 of Set 3 | yellowknife
# Processing Record 24 of Set 3 | changji
# Processing Record 25 of Set 3 | axim
# Processing Record 26 of Set 3 | iqaluit
# Processing Record 27 of Set 3 | homer
# Processing Record 28 of Set 3 | sorong
# Processing Record 29 of Set 3 | longyearbyen
# Processing Record 30 of Set 3 | mulchen
# Processing Record 31 of Set 3 | tabulbah
# City not found. Skipping...
# Processing Record 32 of Set 3 | broome
# Processing Record 33 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 34 of Set 3 | palmas
# Processing Record 35 of Set 3 | mango
# Processing Record 36 of Set 3 | christchurch
# Processing Record 37 of Set 3 | tarko-sale
# Processing Record 38 of Set 3 | bluff
# Processing Record 39 of Set 3 | elban
# Processing Record 40 of Set 3 | cheney
# Processing Record 41 of Set 3 | chapais
# Processing Record 42 of Set 3 | kirsanov
# Processing Record 43 of Set 3 | bowen
# Processing Record 44 of Set 3 | deqing
# Processing Record 45 of Set 3 | barrow
# Processing Record 46 of Set 3 | sao jose da coroa grande
# Processing Record 47 of Set 3 | kaeo
# Processing Record 48 of Set 3 | santa rosa
# Processing Record 49 of Set 3 | am timan
# Processing Record 50 of Set 3 | goderich
# Processing Record 1 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 2 of Set 4 | cosala
# Processing Record 3 of Set 4 | kota kinabalu
# Processing Record 4 of Set 4 | lebu
# Processing Record 5 of Set 4 | mtinko
# Processing Record 6 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 7 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 4 | chekhov
# Processing Record 9 of Set 4 | seminole
# Processing Record 10 of Set 4 | viedma
# Processing Record 11 of Set 4 | severo-kurilsk
# Processing Record 12 of Set 4 | solnechnyy
# Processing Record 13 of Set 4 | fortuna
# Processing Record 14 of Set 4 | samarinda
# Processing Record 15 of Set 4 | norman wells
# Processing Record 16 of Set 4 | kaitangata
# Processing Record 17 of Set 4 | yulara
# Processing Record 18 of Set 4 | hasaki
# Processing Record 19 of Set 4 | carballo
# Processing Record 20 of Set 4 | georgetown
# Processing Record 21 of Set 4 | cozumel
# Processing Record 22 of Set 4 | gaoua
# Processing Record 23 of Set 4 | kiama
# Processing Record 24 of Set 4 | williston
# Processing Record 25 of Set 4 | kenai
# Processing Record 26 of Set 4 | soyo
# Processing Record 27 of Set 4 | ahumada
# City not found. Skipping...
# Processing Record 28 of Set 4 | te anau
# Processing Record 29 of Set 4 | abu zabad
# Processing Record 30 of Set 4 | quatre cocos
# Processing Record 31 of Set 4 | opuwo
# Processing Record 32 of Set 4 | port alfred
# Processing Record 33 of Set 4 | iracoubo
# Processing Record 34 of Set 4 | beringovskiy
# Processing Record 35 of Set 4 | sibolga
# Processing Record 36 of Set 4 | farafangana
# Processing Record 37 of Set 4 | yar-sale
# Processing Record 38 of Set 4 | cidreira
# Processing Record 39 of Set 4 | mar del plata
# Processing Record 40 of Set 4 | saint anthony
# Processing Record 41 of Set 4 | taos
# Processing Record 42 of Set 4 | maniitsoq
# Processing Record 43 of Set 4 | preobrazheniye
# Processing Record 44 of Set 4 | lorengau
# Processing Record 45 of Set 4 | jalu
# Processing Record 46 of Set 4 | chengde
# Processing Record 47 of Set 4 | upernavik
# Processing Record 48 of Set 4 | hithadhoo
# Processing Record 49 of Set 4 | kilindoni
# Processing Record 50 of Set 4 | ahipara
# Processing Record 1 of Set 5 | coihaique
# Processing Record 2 of Set 5 | half moon bay
# Processing Record 3 of Set 5 | nanortalik
# Processing Record 4 of Set 5 | yerbogachen
# Processing Record 5 of Set 5 | shache
# Processing Record 6 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 5 | ngunguru
# Processing Record 9 of Set 5 | puerto leguizamo
# Processing Record 10 of Set 5 | tazmalt
# Processing Record 11 of Set 5 | northam
# Processing Record 12 of Set 5 | bandarbeyla
# Processing Record 13 of Set 5 | tuatapere
# Processing Record 14 of Set 5 | tabuk
# Processing Record 15 of Set 5 | sangar
# Processing Record 16 of Set 5 | suicheng
# Processing Record 17 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 18 of Set 5 | svetlyy
# Processing Record 19 of Set 5 | ludvika
# Processing Record 20 of Set 5 | paracatu
# Processing Record 21 of Set 5 | narsaq
# Processing Record 22 of Set 5 | los llanos de aridane
# Processing Record 23 of Set 5 | strezhevoy
# Processing Record 24 of Set 5 | kavieng
# Processing Record 25 of Set 5 | bubaque
# Processing Record 26 of Set 5 | concepcion
# Processing Record 27 of Set 5 | cockburn town
# Processing Record 28 of Set 5 | gaya
# Processing Record 29 of Set 5 | port blair
# Processing Record 30 of Set 5 | lotoshino
# Processing Record 31 of Set 5 | tupelo
# Processing Record 32 of Set 5 | karanpura
# Processing Record 33 of Set 5 | taoudenni
# Processing Record 34 of Set 5 | husavik
# Processing Record 35 of Set 5 | jamestown
# Processing Record 36 of Set 5 | puerto ayora
# Processing Record 37 of Set 5 | sakakah
# Processing Record 38 of Set 5 | hami
# Processing Record 39 of Set 5 | gostyn
# Processing Record 40 of Set 5 | yerraguntla
# Processing Record 41 of Set 5 | ghotki
# Processing Record 42 of Set 5 | ponta do sol
# Processing Record 43 of Set 5 | shimoda
# Processing Record 44 of Set 5 | quelimane
# Processing Record 45 of Set 5 | krasnoselkup
# Processing Record 46 of Set 5 | lakes entrance
# Processing Record 47 of Set 5 | sedona
# Processing Record 48 of Set 5 | leningradskiy
# Processing Record 49 of Set 5 | ilulissat
# Processing Record 50 of Set 5 | sao goncalo
# Processing Record 1 of Set 6 | lake charles
# Processing Record 2 of Set 6 | amapa
# Processing Record 3 of Set 6 | itarema
# Processing Record 4 of Set 6 | beipiao
# Processing Record 5 of Set 6 | sergeyevka
# Processing Record 6 of Set 6 | grand gaube
# Processing Record 7 of Set 6 | marfino
# Processing Record 8 of Set 6 | srednekolymsk
# Processing Record 9 of Set 6 | talnakh
# Processing Record 10 of Set 6 | chabahar
# Processing Record 11 of Set 6 | miramar
# Processing Record 12 of Set 6 | chiredzi
# Processing Record 13 of Set 6 | hare bay
# Processing Record 14 of Set 6 | puerto colombia
# Processing Record 15 of Set 6 | tommot
# Processing Record 16 of Set 6 | dingle
# Processing Record 17 of Set 6 | karratha
# Processing Record 18 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 6 | babu
# Processing Record 20 of Set 6 | bengkulu
# Processing Record 21 of Set 6 | fairbanks
# Processing Record 22 of Set 6 | tatawin
# Processing Record 23 of Set 6 | kruisfontein
# Processing Record 24 of Set 6 | namibe
# Processing Record 25 of Set 6 | pacatuba
# Processing Record 26 of Set 6 | karasjok
# Processing Record 27 of Set 6 | nishihara
# Processing Record 28 of Set 6 | adwa
# Processing Record 29 of Set 6 | biltine
# Processing Record 30 of Set 6 | bolivar
# Processing Record 31 of Set 6 | diffa
# Processing Record 32 of Set 6 | inhambane
# Processing Record 33 of Set 6 | codrington
# Processing Record 34 of Set 6 | sandnessjoen
# Processing Record 35 of Set 6 | nakatsu
# Processing Record 36 of Set 6 | culpeper
# Processing Record 37 of Set 6 | mandalgovi
# Processing Record 38 of Set 6 | mehamn
# Processing Record 39 of Set 6 | okhotsk
# Processing Record 40 of Set 6 | portland
# Processing Record 41 of Set 6 | pitkyaranta
# Processing Record 42 of Set 6 | odweyne
# Processing Record 43 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 44 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 45 of Set 6 | port keats
# Processing Record 46 of Set 6 | klaksvik
# Processing Record 47 of Set 6 | mason city
# Processing Record 48 of Set 6 | guilin
# Processing Record 49 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 6 | angra
# City not found. Skipping...
# Processing Record 1 of Set 7 | khani
# Processing Record 2 of Set 7 | madimba
# Processing Record 3 of Set 7 | sindand
# City not found. Skipping...
# Processing Record 4 of Set 7 | novi sanzhary
# Processing Record 5 of Set 7 | cabo san lucas
# Processing Record 6 of Set 7 | pisco
# Processing Record 7 of Set 7 | sawtell
# Processing Record 8 of Set 7 | hervey bay
# Processing Record 9 of Set 7 | akyab
# Processing Record 10 of Set 7 | sale
# Processing Record 11 of Set 7 | thayetmyo
# Processing Record 12 of Set 7 | ugoofaaru
# Processing Record 13 of Set 7 | kupang
# Processing Record 14 of Set 7 | ndiekro
# City not found. Skipping...
# Processing Record 15 of Set 7 | lagoa
# Processing Record 16 of Set 7 | hamilton
# Processing Record 17 of Set 7 | garden city
# Processing Record 18 of Set 7 | udachnyy
# Processing Record 19 of Set 7 | mamou
# Processing Record 20 of Set 7 | dehloran
# Processing Record 21 of Set 7 | yeppoon
# Processing Record 22 of Set 7 | harper
# Processing Record 23 of Set 7 | kulhudhuffushi
# Processing Record 24 of Set 7 | epe
# Processing Record 25 of Set 7 | bismarck
# Processing Record 26 of Set 7 | hovd
# Processing Record 27 of Set 7 | ampere
# Processing Record 28 of Set 7 | mattru
# Processing Record 29 of Set 7 | kenitra
# Processing Record 30 of Set 7 | nurota
# Processing Record 31 of Set 7 | geraldton
# Processing Record 32 of Set 7 | mizan teferi
# Processing Record 33 of Set 7 | milingimbi
# City not found. Skipping...
# Processing Record 34 of Set 7 | meulaboh
# Processing Record 35 of Set 7 | diego de almagro
# Processing Record 36 of Set 7 | calvinia
# Processing Record 37 of Set 7 | emba
# Processing Record 38 of Set 7 | buraydah
# Processing Record 39 of Set 7 | chokurdakh
# Processing Record 40 of Set 7 | acapulco
# Processing Record 41 of Set 7 | arman
# Processing Record 42 of Set 7 | amurzet
# Processing Record 43 of Set 7 | kavaratti
# Processing Record 44 of Set 7 | port lincoln
# Processing Record 45 of Set 7 | erenhot
# Processing Record 46 of Set 7 | san patricio
# Processing Record 47 of Set 7 | abu kamal
# Processing Record 48 of Set 7 | tramore
# Processing Record 49 of Set 7 | sao joao da barra
# Processing Record 50 of Set 7 | pierre
# Processing Record 1 of Set 8 | neuquen
# Processing Record 2 of Set 8 | kolyshley
# Processing Record 3 of Set 8 | port hardy
# Processing Record 4 of Set 8 | lavrentiya
# Processing Record 5 of Set 8 | wattegama
# Processing Record 6 of Set 8 | mount vernon
# Processing Record 7 of Set 8 | fochville
# Processing Record 8 of Set 8 | beloha
# Processing Record 9 of Set 8 | newberry
# Processing Record 10 of Set 8 | alofi
# Processing Record 11 of Set 8 | tilichiki
# Processing Record 12 of Set 8 | muli
# Processing Record 13 of Set 8 | noumea
# Processing Record 14 of Set 8 | sinnamary
# Processing Record 15 of Set 8 | pundaguitan
# Processing Record 16 of Set 8 | kobojango
# City not found. Skipping...
# Processing Record 17 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 8 | coria
# Processing Record 19 of Set 8 | santa cruz
# Processing Record 20 of Set 8 | havre-saint-pierre
# Processing Record 21 of Set 8 | batagay-alyta
# Processing Record 22 of Set 8 | ballitoville
# Processing Record 23 of Set 8 | stanovoye
# Processing Record 24 of Set 8 | marzuq
# Processing Record 25 of Set 8 | saint-fabien
# City not found. Skipping...
# Processing Record 26 of Set 8 | skjervoy
# Processing Record 27 of Set 8 | mahanoro
# Processing Record 28 of Set 8 | kutum
# Processing Record 29 of Set 8 | camopi
# Processing Record 30 of Set 8 | sandanski
# Processing Record 31 of Set 8 | turochak
# Processing Record 32 of Set 8 | novikovo
# Processing Record 33 of Set 8 | milkovo
# Processing Record 34 of Set 8 | libertador general san martin
# Processing Record 35 of Set 8 | kurumkan
# Processing Record 36 of Set 8 | nagato
# Processing Record 37 of Set 8 | russkiy aktash
# Processing Record 38 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 39 of Set 8 | tshikapa
# Processing Record 40 of Set 8 | cam ranh
# Processing Record 41 of Set 8 | coquimbo
# Processing Record 42 of Set 8 | valea viilor
# Processing Record 43 of Set 8 | flin flon
# Processing Record 44 of Set 8 | east london
# Processing Record 45 of Set 8 | bluefield
# Processing Record 46 of Set 8 | bonavista
# Processing Record 47 of Set 8 | kindersley
# Processing Record 48 of Set 8 | mapastepec
# Processing Record 49 of Set 8 | moron
# Processing Record 50 of Set 8 | maghama
# City not found. Skipping...
# Processing Record 1 of Set 9 | chicama
# Processing Record 2 of Set 9 | rajshahi
# Processing Record 3 of Set 9 | det udom
# Processing Record 4 of Set 9 | constitucion
# Processing Record 5 of Set 9 | olinda
# Processing Record 6 of Set 9 | bambous virieux
# Processing Record 7 of Set 9 | tra vinh
# Processing Record 8 of Set 9 | arraial do cabo
# Processing Record 9 of Set 9 | luderitz
# Processing Record 10 of Set 9 | tiarei
# Processing Record 11 of Set 9 | harrismith
# Processing Record 12 of Set 9 | dargaville
# Processing Record 13 of Set 9 | coruripe
# Processing Record 14 of Set 9 | kampot
# Processing Record 15 of Set 9 | halifax
# Processing Record 16 of Set 9 | richards bay
# Processing Record 17 of Set 9 | kouroussa
# Processing Record 18 of Set 9 | siguiri
# Processing Record 19 of Set 9 | sitka
# Processing Record 20 of Set 9 | komsomolskiy
# Processing Record 21 of Set 9 | hobyo
# Processing Record 22 of Set 9 | lubango
# Processing Record 23 of Set 9 | mercedes
# Processing Record 24 of Set 9 | necochea
# Processing Record 25 of Set 9 | pakxe
# Processing Record 26 of Set 9 | eenhana
# Processing Record 27 of Set 9 | lasa
# Processing Record 28 of Set 9 | leh
# Processing Record 29 of Set 9 | pingyi
# Processing Record 30 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 9 | broken hill
# Processing Record 32 of Set 9 | la union
# Processing Record 33 of Set 9 | mount gambier
# Processing Record 34 of Set 9 | vardo
# Processing Record 35 of Set 9 | mahalapye
# Processing Record 36 of Set 9 | taltal
# Processing Record 37 of Set 9 | tairua
# Processing Record 38 of Set 9 | risti
# Processing Record 39 of Set 9 | puerto montt
# Processing Record 40 of Set 9 | avera
# Processing Record 41 of Set 9 | margate
# Processing Record 42 of Set 9 | nemuro
# Processing Record 43 of Set 9 | iberia
# Processing Record 44 of Set 9 | sorland
# Processing Record 45 of Set 9 | nizhniy tsasuchey
# Processing Record 46 of Set 9 | jinka
# Processing Record 47 of Set 9 | lucea
# Processing Record 48 of Set 9 | bahia honda
# Processing Record 49 of Set 9 | korla
# Processing Record 50 of Set 9 | colonia
# Processing Record 1 of Set 10 | ostrovnoy
# Processing Record 2 of Set 10 | namatanai
# Processing Record 3 of Set 10 | vao
# Processing Record 4 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 10 | port shepstone
# Processing Record 6 of Set 10 | venkatagiri
# Processing Record 7 of Set 10 | descalvado
# Processing Record 8 of Set 10 | svarstad
# Processing Record 9 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 10 of Set 10 | atar
# Processing Record 11 of Set 10 | tura
# Processing Record 12 of Set 10 | alice springs
# Processing Record 13 of Set 10 | ambon
# Processing Record 14 of Set 10 | mancio lima
# Processing Record 15 of Set 10 | guekedou
# City not found. Skipping...
# Processing Record 16 of Set 10 | morondava
# Processing Record 17 of Set 10 | pochutla
# Processing Record 18 of Set 10 | marawi
# Processing Record 19 of Set 10 | macenta
# Processing Record 20 of Set 10 | sri aman
# Processing Record 21 of Set 10 | kaka
# Processing Record 22 of Set 10 | qasigiannguit
# Processing Record 23 of Set 10 | katima mulilo
# Processing Record 24 of Set 10 | andapa
# Processing Record 25 of Set 10 | dawlatabad
# Processing Record 26 of Set 10 | cascais
# Processing Record 27 of Set 10 | vila franca do campo
# Processing Record 28 of Set 10 | yarada
# Processing Record 29 of Set 10 | vestmannaeyjar
# Processing Record 30 of Set 10 | port moresby
# Processing Record 31 of Set 10 | xghajra
# City not found. Skipping...
# Processing Record 32 of Set 10 | linqiong
# Processing Record 33 of Set 10 | port hedland
# Processing Record 34 of Set 10 | izhma
# Processing Record 35 of Set 10 | sao filipe
# Processing Record 36 of Set 10 | hambantota
# Processing Record 37 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 10 | lahaina
# Processing Record 39 of Set 10 | aklavik
# Processing Record 40 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 10 | san cristobal
# Processing Record 42 of Set 10 | chatakonda
# Processing Record 43 of Set 10 | fort abbas
# Processing Record 44 of Set 10 | kabare
# Processing Record 45 of Set 10 | muros
# Processing Record 46 of Set 10 | karagay
# Processing Record 47 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 10 | neiafu
# Processing Record 49 of Set 10 | tomatlan
# Processing Record 50 of Set 10 | linguere
# Processing Record 1 of Set 11 | bontang
# Processing Record 2 of Set 11 | cernay
# Processing Record 3 of Set 11 | torbay
# Processing Record 4 of Set 11 | mayorga
# Processing Record 5 of Set 11 | balabac
# Processing Record 6 of Set 11 | palmer
# Processing Record 7 of Set 11 | morag
# Processing Record 8 of Set 11 | darab
# Processing Record 9 of Set 11 | cassilandia
# Processing Record 10 of Set 11 | lata
# Processing Record 11 of Set 11 | bhadrachalam
# Processing Record 12 of Set 11 | devarkonda
# Processing Record 13 of Set 11 | sambava
# Processing Record 14 of Set 11 | makakilo city
# Processing Record 15 of Set 11 | bestobe
# Processing Record 16 of Set 11 | adra
# Processing Record 17 of Set 11 | kuusamo
# Processing Record 18 of Set 11 | porto walter
# Processing Record 19 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 11 | antalaha
# Processing Record 21 of Set 11 | burnie
# Processing Record 22 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 11 | melbu
# Processing Record 24 of Set 11 | peleduy
# Processing Record 25 of Set 11 | bilma
# Processing Record 26 of Set 11 | palmerston
# Processing Record 27 of Set 11 | agra
# Processing Record 28 of Set 11 | kochkurovo
# Processing Record 29 of Set 11 | torbat-e jam
# Processing Record 30 of Set 11 | hartford
# Processing Record 31 of Set 11 | kangaatsiaq
# Processing Record 32 of Set 11 | nanpara
# Processing Record 33 of Set 11 | saint-joseph
# Processing Record 34 of Set 11 | chumikan
# Processing Record 35 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 11 | zhezkazgan
# Processing Record 37 of Set 11 | dawson
# Processing Record 38 of Set 11 | ler
# Processing Record 39 of Set 11 | camargo
# Processing Record 40 of Set 11 | den helder
# Processing Record 41 of Set 11 | yonibana
# Processing Record 42 of Set 11 | cayenne
# Processing Record 43 of Set 11 | seoul
# Processing Record 44 of Set 11 | iisalmi
# Processing Record 45 of Set 11 | rocha
# Processing Record 46 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 11 | tabou
# Processing Record 48 of Set 11 | amahai
# Processing Record 49 of Set 11 | worthington
# Processing Record 50 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 12 | belmonte
# Processing Record 2 of Set 12 | paamiut
# Processing Record 3 of Set 12 | chara
# Processing Record 4 of Set 12 | salalah
# Processing Record 5 of Set 12 | chimbote
# Processing Record 6 of Set 12 | chanika
# Processing Record 7 of Set 12 | kibala
# Processing Record 8 of Set 12 | peniche
# Processing Record 9 of Set 12 | roma
# Processing Record 10 of Set 12 | priargunsk
# Processing Record 11 of Set 12 | adiake
# Processing Record 12 of Set 12 | caravelas
# Processing Record 13 of Set 12 | findlay
# Processing Record 14 of Set 12 | zeven
# Processing Record 15 of Set 12 | porto empedocle
# Processing Record 16 of Set 12 | qaqortoq
# Processing Record 17 of Set 12 | bom jesus
# Processing Record 18 of Set 12 | dalbandin
# Processing Record 19 of Set 12 | moscow
# Processing Record 20 of Set 12 | nieuw amsterdam
# Processing Record 21 of Set 12 | port-gentil
# Processing Record 22 of Set 12 | usinsk
# Processing Record 23 of Set 12 | alekseyevsk
# Processing Record 24 of Set 12 | lazaro cardenas
# Processing Record 25 of Set 12 | pedasi
# Processing Record 26 of Set 12 | odessa
# Processing Record 27 of Set 12 | alappuzha
# Processing Record 28 of Set 12 | galesong
# Processing Record 29 of Set 12 | carutapera
# Processing Record 30 of Set 12 | ukiah
# Processing Record 31 of Set 12 | kita
# Processing Record 32 of Set 12 | urumqi
# Processing Record 33 of Set 12 | lithgow
# Processing Record 34 of Set 12 | waipawa
# Processing Record 35 of Set 12 | podyuga
# Processing Record 36 of Set 12 | mae sot
# Processing Record 37 of Set 12 | weiden
# Processing Record 38 of Set 12 | lebanon
# Processing Record 39 of Set 12 | mount isa
# Processing Record 40 of Set 12 | faanui
# Processing Record 41 of Set 12 | huron
# Processing Record 42 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 12 | teya
# Processing Record 44 of Set 12 | kaoma
# Processing Record 45 of Set 12 | ambovombe
# Processing Record 46 of Set 12 | pangnirtung
# Processing Record 47 of Set 12 | vostok
# Processing Record 48 of Set 12 | gravdal
# Processing Record 49 of Set 12 | yangshe
# Processing Record 50 of Set 12 | mabaruma
# Processing Record 1 of Set 13 | ca mau
# Processing Record 2 of Set 13 | vanavara
# Processing Record 3 of Set 13 | anlu
# Processing Record 4 of Set 13 | vila
# Processing Record 5 of Set 13 | tautira
# Processing Record 6 of Set 13 | delta del tigre
# Processing Record 7 of Set 13 | dauriya
# Processing Record 8 of Set 13 | rawson
# Processing Record 9 of Set 13 | kontagora
# Processing Record 10 of Set 13 | north bend
# Processing Record 11 of Set 13 | salinas
# Processing Record 12 of Set 13 | shahr-e babak
# Processing Record 13 of Set 13 | adrar
# Processing Record 14 of Set 13 | kahului
# Processing Record 15 of Set 13 | cavalcante
# Processing Record 16 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 17 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 13 | konya
# Processing Record 19 of Set 13 | sakaiminato
# Processing Record 20 of Set 13 | lenger
# Processing Record 21 of Set 13 | cabedelo
# Processing Record 22 of Set 13 | samarai
# Processing Record 23 of Set 13 | belton
# Processing Record 24 of Set 13 | abalak
# Processing Record 25 of Set 13 | touros
# Processing Record 26 of Set 13 | aborlan
# Processing Record 27 of Set 13 | dera ghazi khan
# Processing Record 28 of Set 13 | miles city
# Processing Record 29 of Set 13 | saint-louis
# Processing Record 30 of Set 13 | sebezh
# Processing Record 31 of Set 13 | cairns
# Processing Record 32 of Set 13 | jardim
# Processing Record 33 of Set 13 | nizhniy odes
# Processing Record 34 of Set 13 | pafos
# Processing Record 35 of Set 13 | riverton
# Processing Record 36 of Set 13 | manakara
# Processing Record 37 of Set 13 | casambalangan
# Processing Record 38 of Set 13 | sechura
# Processing Record 39 of Set 13 | vanimo
# Processing Record 40 of Set 13 | alanya
# Processing Record 41 of Set 13 | katherine
# Processing Record 42 of Set 13 | tunghsiao
# City not found. Skipping...
# Processing Record 43 of Set 13 | santiago del estero
# Processing Record 44 of Set 13 | santa fe
# Processing Record 45 of Set 13 | orocue
# Processing Record 46 of Set 13 | oudtshoorn
# Processing Record 47 of Set 13 | nioro
# Processing Record 48 of Set 13 | khandbari
# Processing Record 49 of Set 13 | maragogi
# Processing Record 50 of Set 13 | sinjai
# Processing Record 1 of Set 14 | san quintin
# Processing Record 2 of Set 14 | krasnyy profintern
# Processing Record 3 of Set 14 | batticaloa
# Processing Record 4 of Set 14 | aswan
# Processing Record 5 of Set 14 | remanso
# Processing Record 6 of Set 14 | valparaiso
# Processing Record 7 of Set 14 | sola
# Processing Record 8 of Set 14 | ngama
# Processing Record 9 of Set 14 | xiuyan
# Processing Record 10 of Set 14 | sovetskiy
# Processing Record 11 of Set 14 | oksfjord
# Processing Record 12 of Set 14 | staroleushkovskaya
# Processing Record 13 of Set 14 | tarnova
# Processing Record 14 of Set 14 | ballstad
# City not found. Skipping...
# Processing Record 15 of Set 14 | oranjemund
# Processing Record 16 of Set 14 | bukachacha
# Processing Record 17 of Set 14 | pacific grove
# Processing Record 18 of Set 14 | ouadda
# Processing Record 19 of Set 14 | boa vista
# Processing Record 20 of Set 14 | kaniama
# Processing Record 21 of Set 14 | coahuayana
# Processing Record 22 of Set 14 | tabory
# Processing Record 23 of Set 14 | booue
# Processing Record 24 of Set 14 | tolu
# Processing Record 25 of Set 14 | boueni
# Processing Record 26 of Set 14 | el tigre
# Processing Record 27 of Set 14 | chase
# Processing Record 28 of Set 14 | marang
# Processing Record 29 of Set 14 | conceicao do araguaia
# Processing Record 30 of Set 14 | poum
# Processing Record 31 of Set 14 | porto santo
# Processing Record 32 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 14 | amuntai
# Processing Record 34 of Set 14 | dosso
# Processing Record 35 of Set 14 | chitral
# Processing Record 36 of Set 14 | curup
# Processing Record 37 of Set 14 | roches noires
# City not found. Skipping...
# Processing Record 38 of Set 14 | tupik
# Processing Record 39 of Set 14 | constantine
# Processing Record 40 of Set 14 | lakatoro
# Processing Record 41 of Set 14 | bani
# Processing Record 42 of Set 14 | aginskoye
# Processing Record 43 of Set 14 | tual
# Processing Record 44 of Set 14 | aba
# Processing Record 45 of Set 14 | yumen
# Processing Record 46 of Set 14 | luanda
# Processing Record 47 of Set 14 | phumi samraong
# City not found. Skipping...
# Processing Record 48 of Set 14 | lawrenceburg
# Processing Record 49 of Set 14 | tolmachevo
# Processing Record 50 of Set 14 | batagay
# Processing Record 1 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 3 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 15 | kamiiso
# Processing Record 5 of Set 15 | jacmel
# Processing Record 6 of Set 15 | moose factory
# Processing Record 7 of Set 15 | coshocton
# Processing Record 8 of Set 15 | fotolivos
# Processing Record 9 of Set 15 | kjollefjord
# Processing Record 10 of Set 15 | isla mujeres
# Processing Record 11 of Set 15 | chillan
# Processing Record 12 of Set 15 | buchanan
# Processing Record 13 of Set 15 | mahibadhoo
# Processing Record 14 of Set 15 | boda
# Processing Record 15 of Set 15 | truckee
# Processing Record 16 of Set 15 | jieshou
# Processing Record 17 of Set 15 | mosquera
# Processing Record 18 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 19 of Set 15 | sobolevo
# Processing Record 20 of Set 15 | namtsy
# Processing Record 21 of Set 15 | mont-de-marsan
# Processing Record 22 of Set 15 | darien
# Processing Record 23 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 24 of Set 15 | grand-santi
# Processing Record 25 of Set 15 | waingapu
# Processing Record 26 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 27 of Set 15 | araripe
# Processing Record 28 of Set 15 | dunmore town
# Processing Record 29 of Set 15 | wembley
# Processing Record 30 of Set 15 | promyshlennaya
# Processing Record 31 of Set 15 | porto novo
# Processing Record 32 of Set 15 | nantucket
# Processing Record 33 of Set 15 | pathankot
# Processing Record 34 of Set 15 | khasan
# Processing Record 35 of Set 15 | lusambo
# Processing Record 36 of Set 15 | sioux lookout
# Processing Record 37 of Set 15 | palu
# Processing Record 38 of Set 15 | archidona
# Processing Record 39 of Set 15 | tongliao
# Processing Record 40 of Set 15 | yokadouma
# Processing Record 41 of Set 15 | lesna
# Processing Record 42 of Set 15 | caxito
# Processing Record 43 of Set 15 | de aar
# Processing Record 44 of Set 15 | tornio
# Processing Record 45 of Set 15 | male
# Processing Record 46 of Set 15 | denpasar
# Processing Record 47 of Set 15 | powder springs
# Processing Record 48 of Set 15 | crixas
# Processing Record 49 of Set 15 | goba
# Processing Record 50 of Set 15 | cataguases
# Processing Record 1 of Set 16 | zorritos
# Processing Record 2 of Set 16 | araouane
# Processing Record 3 of Set 16 | puerto del rosario
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 692

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         city      lat       Lng  Max temp  Humidity  Cloudiness  Wind Speed  \
# 0     Igarka  67.4667   86.5833      3.33        99         100        7.83
# 1     Mpanda  -6.3655   31.0409     73.06        49          93        1.74
# 2     Dikson  73.5069   80.5464     20.68        91         100        5.77
# 3     Albany  42.6001  -73.9662     57.58        66           0        3.58
# 4     Atuona  -9.8000 -139.0333     77.54        79          19       12.64
# 5   Bagdarin  54.4333  113.6000     15.82        63         100        4.61
# 6    Rikitea -23.1203 -134.9692     70.07        68         100       15.73
# 7  Busselton -33.6500  115.3333     61.41        78          16       11.32
# 8     Payson  40.0444 -111.7321     38.59        72         100        1.99
# 9    Qaanaaq  77.4840  -69.3632      8.15        53          32        9.08
#
#   Country Current Description
# 0      RU     overcast clouds
# 1      TZ     overcast clouds
# 2      RU     overcast clouds
# 3      US           clear sky
# 4      PF          few clouds
# 5      RU     overcast clouds
# 6      PF     overcast clouds
# 7      AU          few clouds
# 8      US     overcast clouds
# 9      GL    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['city', 'lat', 'Lng', 'Max temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Display sample data
city_data_df.head(10)
# Out:
#         city      lat       Lng  Max temp  Humidity  Cloudiness  Wind Speed  \
# 0     Igarka  67.4667   86.5833      3.33        99         100        7.83
# 1     Mpanda  -6.3655   31.0409     73.06        49          93        1.74
# 2     Dikson  73.5069   80.5464     20.68        91         100        5.77
# 3     Albany  42.6001  -73.9662     57.58        66           0        3.58
# 4     Atuona  -9.8000 -139.0333     77.54        79          19       12.64
# 5   Bagdarin  54.4333  113.6000     15.82        63         100        4.61
# 6    Rikitea -23.1203 -134.9692     70.07        68         100       15.73
# 7  Busselton -33.6500  115.3333     61.41        78          16       11.32
# 8     Payson  40.0444 -111.7321     38.59        72         100        1.99
# 9    Qaanaaq  77.4840  -69.3632      8.15        53          32        9.08
#
#   Country Current Description
# 0      RU     overcast clouds
# 1      TZ     overcast clouds
# 2      RU     overcast clouds
# 3      US           clear sky
# 4      PF          few clouds
# 5      RU     overcast clouds
# 6      PF     overcast clouds
# 7      AU          few clouds
# 8      US     overcast clouds
# 9      GL    scattered clouds

# %%
city_data_df.rename(columns={'city':'City','lat': 'Lat', 'Max temp':'Max Temp'}, inplace=True)

# %%
city_data_df
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                Igarka  67.4667   86.5833      3.33        99         100
# 1                Mpanda  -6.3655   31.0409     73.06        49          93
# 2                Dikson  73.5069   80.5464     20.68        91         100
# 3                Albany  42.6001  -73.9662     57.58        66           0
# 4                Atuona  -9.8000 -139.0333     77.54        79          19
# ..                  ...      ...       ...       ...       ...         ...
# 687                Goba   7.0167   39.9833     44.51        86          22
# 688          Cataguases -21.3892  -42.6967     64.65        87         100
# 689            Zorritos  -3.6805  -80.6782     70.09        75          21
# 690            Araouane  18.9048   -3.5265     73.85        15           0
# 691  Puerto Del Rosario  28.5004  -13.8627     73.15        78          40
#
#      Wind Speed Country Current Description
# 0          7.83      RU     overcast clouds
# 1          1.74      TZ     overcast clouds
# 2          5.77      RU     overcast clouds
# 3          3.58      US           clear sky
# 4         12.64      PF          few clouds
# ..          ...     ...                 ...
# 687        5.06      ET          few clouds
# 688        2.53      BR     overcast clouds
# 689       12.66      PE          few clouds
# 690        9.10      ML           clear sky
# 691       12.66      ES    scattered clouds
#
# [692 rows x 9 columns]

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City","Country", "Lat", "Lng", "Max Temp","Humidity", "Cloudiness","Wind Speed","Current Description"]
# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Igarka      RU  67.4667   86.5833      3.33        99         100
# 1     Mpanda      TZ  -6.3655   31.0409     73.06        49          93
# 2     Dikson      RU  73.5069   80.5464     20.68        91         100
# 3     Albany      US  42.6001  -73.9662     57.58        66           0
# 4     Atuona      PF  -9.8000 -139.0333     77.54        79          19
# 5   Bagdarin      RU  54.4333  113.6000     15.82        63         100
# 6    Rikitea      PF -23.1203 -134.9692     70.07        68         100
# 7  Busselton      AU -33.6500  115.3333     61.41        78          16
# 8     Payson      US  40.0444 -111.7321     38.59        72         100
# 9    Qaanaaq      GL  77.4840  -69.3632      8.15        53          32
#
#    Wind Speed Current Description
# 0        7.83     overcast clouds
# 1        1.74     overcast clouds
# 2        5.77     overcast clouds
# 3        3.58           clear sky
# 4       12.64          few clouds
# 5        4.61     overcast clouds
# 6       15.73     overcast clouds
# 7       11.32          few clouds
# 8        1.99     overcast clouds
# 9        9.08    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
